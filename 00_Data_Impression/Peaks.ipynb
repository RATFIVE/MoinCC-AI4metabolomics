# %%
from classes import DataParser
from classes import PeakFinder
import numpy as np
import pandas as pd

# import gaussian noise filter
from scipy.ndimage import gaussian_filter

# %%
dataparser = DataParser()
data_list = dataparser.load_data()

for i in range(len(data_list)):
    df = dataparser.load_df(data_list[i])
    

    print(f"Data {i}: {data_list[i]}")
    # sum all columns from 1 to len(df.columns)
    df['sum'] = df.iloc[:, 1:].sum(axis=1)

    x = df.iloc[:, 0].values
    y = df['sum'].values

    
    

    peakfinder = PeakFinder()
    peaks, prob, tresh = peakfinder.peaks_finder(y)
    


    peak_pos_list = np.array([2.323, 6.653, 9.094, 8.876, 8.420, 7.772, 2.468, 4.7, 1.201, 4.368, 2.475, 9.031, 8.714, 8.376, 7.659, 1.2261, 1.9775])
    
    true_peaks = []
    # check if peak is close to the peak_pos_list
    bound = 0.2
    for peak in peaks:
        for peak_pos in peak_pos_list:
            if x[peak] - bound <= peak_pos <= x[peak] + bound:
                #print(f"Peak {peak} is close to peak_pos {peak_pos}")
                true_peaks.append(peak)


    import matplotlib.pyplot as plt
    plt.plot(x, y, label='Data', color='blue')
    # plot horizontal line at threshold
    plt.axhline(tresh, color='green', linestyle='--')

    # plot vertical lines at peaks
    for peak in peak_pos_list:
        plt.axvline(peak, color='orange', linestyle='--', alpha=0.8, label='Metabolite Position')

    for peak in true_peaks:
        plt.axvline(x[peak], color='green', linestyle='--', alpha=0.8, label='Peak in Range of Metabolite Position')
    
    plt.scatter(x[true_peaks], y[true_peaks], color='red', label='Found Peaks')
    plt.title(f"Data {i}")
    # Legend with grouped labels
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())
    plt.show()
# Out:
# Working Dir: /Users/marco/Documents/MoinCC-AI4metabolomics/00_Data_Impression
# Data 0: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20231206_2H_yeast_Pyruvate-d3_1.ser.csv
# Data 1: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_5_200.ser.csv
# Data 2: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_7_0.ser.csv
# Data 3: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240514_2H_yeast_Nicotinamide-d4 _6.csv
# Data 4: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20231206_2H_yeast_Pyruvate-d3_2.csv
# Data 5: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240731_2H_yeast_Fumarate-d2_14_320.ser.csv
# Data 6: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _7.csv
# Data 7: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240207_2H_yeast_Pyruvate-d3_3.csv
# Data 8: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_12_0.ser.csv
# Data 9: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240108_2H_yeast_Nicotinamide-d4 _11.csv
# Data 10: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _6.csv
# Data 11: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_8_25.ser.csv
# Data 12: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _4.csv
# Data 13: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240205_2H_yeast_acetone-d6_2.csv
# Data 14: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240213_2H_yeast_Fumarate-d2_9.csv
# Data 15: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _5.csv
# Data 16: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_4_320.ser.csv
# Data 17: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240207_2H_yeast_Pyruvate-d3_4.csv
# Data 18: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240701_2H_yeast_Fumarate-d2_5.csv
# Data 19: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240228_2H_yeast_fumarate-d2_4.csv
# Data 20: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240207_2H_yeast_Fumarate-d2_5.csv
# Data 21: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240731_2H_yeast_Fumarate-d2_15_200.ser.csv
# Data 22: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20231206_2H_yeast_Pyruvate_2.ser.csv
# Data 23: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240701_2H_yeast_Fumarate-d2_7.csv
# Data 24: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240701_2H_yeast_Fumarate-d2_6.csv
# Data 25: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _3.csv
# Data 26: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_4_400.ser.csv
# Data 27: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20231122_2H_yeast_acetone-d6_1.csv
# Data 28: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240704_2H_yeast_Fumarate-d2_6.csv
# Data 29: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240124_2H_yeast_Nicotinamide-d4 _5.csv
# Data 30: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240704_2H_yeast_Fumarate-d2_4.csv
# Data 31: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240701_2H_yeast_Fumarate-d2_8.csv
# Data 32: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240729_2H_yeast_Fumarate-d2_6_100.ser.csv
# Data 33: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _8.csv
# Data 34: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240517_2H_yeast_Nicotinamide-d4 _9.csv
# Data 35: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20231113_2H_yeast_Pyruvate-d3_1.csv
# Data 36: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240108_2H_yeast_Nicotinamide-d4 _7.csv
# Data 37: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240704_2H_yeast_Fumarate-d2_3.csv
# Data 38: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240715_2H_yeast_Fumarate-d2_6_320.ser.csv
# Data 39: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240206_2H_yeast l _acetone-d6_1.csv
# Data 40: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240715_2H_yeast_Fumarate-d2_5_25.ser.csv
# Data 41: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240206_2H_yeast_acetone-d6_3.csv
# Data 42: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240715_2H_yeast_Fumarate-d2_4_200.ser.csv
# Data 43: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240715_2H_yeast_Fumarate-d2_3_320.ser.csv
# Data 44: /Users/marco/Documents/MoinCC-AI4metabolomics/Data/FA_20240215_2H_yeast_Pyruvate-d3_5.csv
